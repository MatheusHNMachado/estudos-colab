# %%
ticked = 320.52
vendas =  3
print(ticked * vendas)
# Out:
# 961.56

# %%
total = 834.47
medio = 119.21
print(int(total / medio))
# Out:
# 7

# %%
total = 15378.12
quantidade = 5
print(total / quantidade)
# Out:
# 3075.6240000000003

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'

print(cancao.upper())
# Out:
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'

print(cancao.lower())
# Out:
# roda mundo, roda gigante, roda moinho, roda pião.

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'

print(cancao.replace('mundo', 'matheus'))
# Out:
# Roda matheus, roda gigante, roda moinho, roda pião.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'

print(noticia.find("2,75%"))
print(noticia.find("6"))
# Out:
# 12
# 62

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'

inicio_selic = noticia.find("2,75%")
print(inicio_selic)

selic = noticia[inicio_selic:inicio_selic+5]
print(selic)

inicio_ano = noticia.find("6")

ano = noticia[inicio_ano:inicio_ano+1]
print(ano)
# Out:
# 12
# 2,75%
# 6

# %%
a = False
b = True

x = not a & b
print("Resultado booleano:", x)
# Out:
# Resultado booleano: True

# %%
# Soma de dados
simples = [10, 20, 30, 40]
media = sum(simples) / len(simples)
print(f'Média dos dados: {media}')
# Out:
# Média dos dados: 25.0

# %%
# Lista de notas dos alunos
notas = [85, 92, 78, 90, 88]

# Calcula a média das notas
soma = 0
for nota in notas:
    soma += nota
media = soma / len(notas)

# Classifica os alunos com base na média
alunos_aprovados = []
alunos_reprovados = []

for nota in notas:
    if nota >= media:
        alunos_aprovados.append(nota)
    else:
        alunos_reprovados.append(nota)

print("Notas dos alunos:", notas ,"\n")
print("Média das notas:", media ,"\n")
print("Alunos aprovados:", alunos_aprovados ,"\n")
print("Alunos reprovados:", alunos_reprovados)
# Out:
# Notas dos alunos: [85, 92, 78, 90, 88]
#
# Média das notas: 86.6
#
# Alunos aprovados: [92, 90, 88]
#
# Alunos reprovados: [85, 78]

# %%
nome_usuario = input("Por favor, insira seu nome de usuário:")
print ( f"Olá, {nome_usuario}! Bem-vindo ao nosso sistema")

idade_inteira_usuario = int(input ("Por favor, insira sua idade: "))

if idade_inteira_usuario >= 18 :
    print("Você é maior de idade.")
else :
    print("Você é menor de idade.")
# Out:
# Por favor, insira seu nome de usuário:Matheus
# Olá, Matheus! Bem-vindo ao nosso sistema
# Por favor, insira sua idade: 26
# Você é maior de idade.
